# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import copy
import random
import math
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv("train.csv")
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43957 entries, 0 to 43956
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              43957 non-null  int64
#  1   workclass        41459 non-null  object
#  2   fnlwgt           43957 non-null  int64
#  3   education        43957 non-null  object
#  4   educational-num  43957 non-null  int64
#  5   marital-status   43957 non-null  object
#  6   occupation       41451 non-null  object
#  7   relationship     43957 non-null  object
#  8   race             43957 non-null  object
#  9   gender           43957 non-null  object
#  10  capital-gain     43957 non-null  int64
#  11  capital-loss     43957 non-null  int64
#  12  hours-per-week   43957 non-null  int64
#  13  native-country   43194 non-null  object
#  14  income_>50K      43957 non-null  int64
# dtypes: int64(7), object(8)
# memory usage: 5.0+ MB

# %%
train_df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   67    Private  366425     Doctorate               16            Divorced
# 1   17    Private  244602          12th                8       Never-married
# 2   31    Private  174201     Bachelors               13  Married-civ-spouse
# 3   58  State-gov  110199       7th-8th                4  Married-civ-spouse
# 4   25  State-gov  149248  Some-college               10       Never-married
#
#          occupation   relationship   race gender  capital-gain  capital-loss  \
# 0   Exec-managerial  Not-in-family  White   Male         99999             0
# 1     Other-service      Own-child  White   Male             0             0
# 2   Exec-managerial        Husband  White   Male             0             0
# 3  Transport-moving        Husband  White   Male             0             0
# 4     Other-service  Not-in-family  Black   Male             0             0
#
#    hours-per-week native-country  income_>50K
# 0              60  United-States            1
# 1              15  United-States            0
# 2              40  United-States            1
# 3              40  United-States            0
# 4              40  United-States            0

# %%
train_df.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  43957.000000  4.395700e+04     43957.000000  43957.000000
# mean      38.617149  1.896730e+05        10.074118   1093.559797
# std       13.734401  1.058215e+05         2.575092   7570.536063
# min       17.000000  1.349200e+04         1.000000      0.000000
# 25%       28.000000  1.174960e+05         9.000000      0.000000
# 50%       37.000000  1.781000e+05        10.000000      0.000000
# 75%       48.000000  2.376710e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week   income_>50K
# count  43957.000000    43957.000000  43957.000000
# mean      88.246491       40.407694      0.239279
# std      404.588410       12.400303      0.426648
# min        0.000000        1.000000      0.000000
# 25%        0.000000       40.000000      0.000000
# 50%        0.000000       40.000000      0.000000
# 75%        0.000000       45.000000      0.000000
# max     4356.000000       99.000000      1.000000

# %%
test_df = pd.read_csv("test.csv")
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 899 entries, 0 to 898
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              899 non-null    int64
#  1   workclass        899 non-null    object
#  2   fnlwgt           899 non-null    int64
#  3   education        899 non-null    object
#  4   educational-num  899 non-null    int64
#  5   marital-status   899 non-null    object
#  6   occupation       899 non-null    object
#  7   relationship     899 non-null    object
#  8   race             899 non-null    object
#  9   gender           899 non-null    object
#  10  capital-gain     899 non-null    int64
#  11  capital-loss     899 non-null    int64
#  12  hours-per-week   899 non-null    int64
#  13  native-country   899 non-null    object
# dtypes: int64(6), object(8)
# memory usage: 98.5+ KB

# %%
test_df.head()
# Out:
#    age         workclass  fnlwgt   education  educational-num  \
# 0   39  Self-emp-not-inc  327120     HS-grad                9
# 1   32           Private  123253  Assoc-acdm               12
# 2   47           Private  232628     HS-grad                9
# 3   19           Private  374262        12th                8
# 4   46  Self-emp-not-inc  311231     HS-grad                9
#
#        marital-status         occupation relationship   race gender  \
# 0  Married-civ-spouse       Craft-repair      Husband  White   Male
# 1  Married-civ-spouse       Craft-repair      Husband  White   Male
# 2  Married-civ-spouse       Craft-repair      Husband  Black   Male
# 3       Never-married  Handlers-cleaners    Own-child  White   Male
# 4  Married-civ-spouse    Farming-fishing      Husband  White   Male
#
#    capital-gain  capital-loss  hours-per-week native-country
# 0             0             0              40       Portugal
# 1             0             0              42  United-States
# 2             0             0              40  United-States
# 3             0             0              20  United-States
# 4             0             0              40  United-States

# %%
# filter native country for only US results
# get rid of capital gain, capital loss, and fnlwgt columns
# fill any null values with "unknown" (safety net, although there do not seem to be any missing)
def clean_data(df):
    df = df[df["native-country"] == "United-States"]
    
    df = df.drop(columns=["fnlwgt", "capital-gain", "capital-loss"])
    
    df["workclass"] = df["workclass"].fillna("Unknown")
    df["occupation"] = df["occupation"].fillna("Unknown")
    
    return df

train_df = clean_data(train_df)
test_df = clean_data(test_df)

# %%
train_df.head()
# Out:
#    age  workclass     education  educational-num      marital-status  \
# 0   67    Private     Doctorate               16            Divorced
# 1   17    Private          12th                8       Never-married
# 2   31    Private     Bachelors               13  Married-civ-spouse
# 3   58  State-gov       7th-8th                4  Married-civ-spouse
# 4   25  State-gov  Some-college               10       Never-married
#
#          occupation   relationship   race gender  hours-per-week  \
# 0   Exec-managerial  Not-in-family  White   Male              60
# 1     Other-service      Own-child  White   Male              15
# 2   Exec-managerial        Husband  White   Male              40
# 3  Transport-moving        Husband  White   Male              40
# 4     Other-service  Not-in-family  Black   Male              40
#
#   native-country  income_>50K
# 0  United-States            1
# 1  United-States            0
# 2  United-States            1
# 3  United-States            0
# 4  United-States            0

# %%
test_df.head()
# Out:
#    age         workclass   education  educational-num      marital-status  \
# 1   32           Private  Assoc-acdm               12  Married-civ-spouse
# 2   47           Private     HS-grad                9  Married-civ-spouse
# 3   19           Private        12th                8       Never-married
# 4   46  Self-emp-not-inc     HS-grad                9  Married-civ-spouse
# 5   45           Private   Bachelors               13  Married-civ-spouse
#
#           occupation relationship   race gender  hours-per-week native-country
# 1       Craft-repair      Husband  White   Male              42  United-States
# 2       Craft-repair      Husband  Black   Male              40  United-States
# 3  Handlers-cleaners    Own-child  White   Male              20  United-States
# 4    Farming-fishing      Husband  White   Male              40  United-States
# 5     Prof-specialty      Husband  White   Male              50  United-States

# %%
# encoding 
train_df_encoding = pd.get_dummies(train_df, columns= ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'gender', 'native-country'], dtype=int)
test_df_encoding = pd.get_dummies(test_df, columns= ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'gender', 'native-country'], dtype=int)
train_df_encoding.head()
test_df_encoding.head()
train_df_encoding.info()
test_df_encoding.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39429 entries, 0 to 43956
# Data columns (total 65 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   age                                   39429 non-null  int64
#  1   educational-num                       39429 non-null  int64
#  2   hours-per-week                        39429 non-null  int64
#  3   income_>50K                           39429 non-null  int64
#  4   workclass_Federal-gov                 39429 non-null  int32
#  5   workclass_Local-gov                   39429 non-null  int32
#  6   workclass_Never-worked                39429 non-null  int32
#  7   workclass_Private                     39429 non-null  int32
#  8   workclass_Self-emp-inc                39429 non-null  int32
#  9   workclass_Self-emp-not-inc            39429 non-null  int32
#  10  workclass_State-gov                   39429 non-null  int32
#  11  workclass_Unknown                     39429 non-null  int32
#  12  workclass_Without-pay                 39429 non-null  int32
#  13  education_10th                        39429 non-null  int32
#  14  education_11th                        39429 non-null  int32
#  15  education_12th                        39429 non-null  int32
#  16  education_1st-4th                     39429 non-null  int32
#  17  education_5th-6th                     39429 non-null  int32
#  18  education_7th-8th                     39429 non-null  int32
#  19  education_9th                         39429 non-null  int32
#  20  education_Assoc-acdm                  39429 non-null  int32
#  21  education_Assoc-voc                   39429 non-null  int32
#  22  education_Bachelors                   39429 non-null  int32
#  23  education_Doctorate                   39429 non-null  int32
#  24  education_HS-grad                     39429 non-null  int32
#  25  education_Masters                     39429 non-null  int32
#  26  education_Preschool                   39429 non-null  int32
#  27  education_Prof-school                 39429 non-null  int32
#  28  education_Some-college                39429 non-null  int32
#  29  marital-status_Divorced               39429 non-null  int32
#  30  marital-status_Married-AF-spouse      39429 non-null  int32
#  31  marital-status_Married-civ-spouse     39429 non-null  int32
#  32  marital-status_Married-spouse-absent  39429 non-null  int32
#  33  marital-status_Never-married          39429 non-null  int32
#  34  marital-status_Separated              39429 non-null  int32
#  35  marital-status_Widowed                39429 non-null  int32
#  36  occupation_Adm-clerical               39429 non-null  int32
#  37  occupation_Armed-Forces               39429 non-null  int32
#  38  occupation_Craft-repair               39429 non-null  int32
#  39  occupation_Exec-managerial            39429 non-null  int32
#  40  occupation_Farming-fishing            39429 non-null  int32
#  41  occupation_Handlers-cleaners          39429 non-null  int32
#  42  occupation_Machine-op-inspct          39429 non-null  int32
#  43  occupation_Other-service              39429 non-null  int32
#  44  occupation_Priv-house-serv            39429 non-null  int32
#  45  occupation_Prof-specialty             39429 non-null  int32
#  46  occupation_Protective-serv            39429 non-null  int32
#  47  occupation_Sales                      39429 non-null  int32
#  48  occupation_Tech-support               39429 non-null  int32
#  49  occupation_Transport-moving           39429 non-null  int32
#  50  occupation_Unknown                    39429 non-null  int32
#  51  relationship_Husband                  39429 non-null  int32
#  52  relationship_Not-in-family            39429 non-null  int32
#  53  relationship_Other-relative           39429 non-null  int32
#  54  relationship_Own-child                39429 non-null  int32
#  55  relationship_Unmarried                39429 non-null  int32
#  56  relationship_Wife                     39429 non-null  int32
#  57  race_Amer-Indian-Eskimo               39429 non-null  int32
#  58  race_Asian-Pac-Islander               39429 non-null  int32
#  59  race_Black                            39429 non-null  int32
#  60  race_Other                            39429 non-null  int32
#  61  race_White                            39429 non-null  int32
#  62  gender_Female                         39429 non-null  int32
#  63  gender_Male                           39429 non-null  int32
#  64  native-country_United-States          39429 non-null  int32
# dtypes: int32(61), int64(4)
# memory usage: 10.7 MB
# <class 'pandas.core.frame.DataFrame'>
# Index: 819 entries, 1 to 898
# Data columns (total 59 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   age                                   819 non-null    int64
#  1   educational-num                       819 non-null    int64
#  2   hours-per-week                        819 non-null    int64
#  3   workclass_Federal-gov                 819 non-null    int32
#  4   workclass_Local-gov                   819 non-null    int32
#  5   workclass_Private                     819 non-null    int32
#  6   workclass_Self-emp-inc                819 non-null    int32
#  7   workclass_Self-emp-not-inc            819 non-null    int32
#  8   workclass_State-gov                   819 non-null    int32
#  9   education_10th                        819 non-null    int32
#  10  education_11th                        819 non-null    int32
#  11  education_12th                        819 non-null    int32
#  12  education_1st-4th                     819 non-null    int32
#  13  education_5th-6th                     819 non-null    int32
#  14  education_7th-8th                     819 non-null    int32
#  15  education_9th                         819 non-null    int32
#  16  education_Assoc-acdm                  819 non-null    int32
#  17  education_Assoc-voc                   819 non-null    int32
#  18  education_Bachelors                   819 non-null    int32
#  19  education_Doctorate                   819 non-null    int32
#  20  education_HS-grad                     819 non-null    int32
#  21  education_Masters                     819 non-null    int32
#  22  education_Prof-school                 819 non-null    int32
#  23  education_Some-college                819 non-null    int32
#  24  marital-status_Divorced               819 non-null    int32
#  25  marital-status_Married-AF-spouse      819 non-null    int32
#  26  marital-status_Married-civ-spouse     819 non-null    int32
#  27  marital-status_Married-spouse-absent  819 non-null    int32
#  28  marital-status_Never-married          819 non-null    int32
#  29  marital-status_Separated              819 non-null    int32
#  30  marital-status_Widowed                819 non-null    int32
#  31  occupation_Adm-clerical               819 non-null    int32
#  32  occupation_Armed-Forces               819 non-null    int32
#  33  occupation_Craft-repair               819 non-null    int32
#  34  occupation_Exec-managerial            819 non-null    int32
#  35  occupation_Farming-fishing            819 non-null    int32
#  36  occupation_Handlers-cleaners          819 non-null    int32
#  37  occupation_Machine-op-inspct          819 non-null    int32
#  38  occupation_Other-service              819 non-null    int32
#  39  occupation_Priv-house-serv            819 non-null    int32
#  40  occupation_Prof-specialty             819 non-null    int32
#  41  occupation_Protective-serv            819 non-null    int32
#  42  occupation_Sales                      819 non-null    int32
#  43  occupation_Tech-support               819 non-null    int32
#  44  occupation_Transport-moving           819 non-null    int32
#  45  relationship_Husband                  819 non-null    int32
#  46  relationship_Not-in-family            819 non-null    int32
#  47  relationship_Other-relative           819 non-null    int32
#  48  relationship_Own-child                819 non-null    int32
#  49  relationship_Unmarried                819 non-null    int32
#  50  relationship_Wife                     819 non-null    int32
#  51  race_Amer-Indian-Eskimo               819 non-null    int32
#  52  race_Asian-Pac-Islander               819 non-null    int32
#  53  race_Black                            819 non-null    int32
#  54  race_Other                            819 non-null    int32
#  55  race_White                            819 non-null    int32
#  56  gender_Female                         819 non-null    int32
#  57  gender_Male                           819 non-null    int32
#  58  native-country_United-States          819 non-null    int32
# dtypes: int32(56), int64(3)
# memory usage: 204.8 KB

# %%
train_df_encoding, test_df_encoding = train_df_encoding.align(
    test_df_encoding, join='left', axis=1, fill_value=0)

# %%
set(train_df_encoding.columns)==set(test_df_encoding.columns)
# Out:
# True

# %%
numeric_cols = ['age', 'hours-per-week']
scaler = StandardScaler()
# fitting the scaler only to the train data
scaler.fit(train_df[numeric_cols])
# transforming both train and test
train_df_encoding[numeric_cols] = scaler.transform(train_df_encoding[numeric_cols])
test_df_encoding[numeric_cols] = scaler.transform(test_df_encoding[numeric_cols])
# print
print("Scaled train head:", train_df_encoding[numeric_cols].head())
print("Scaled train describe:", train_df_encoding[numeric_cols].describe())
# Out:
# Scaled train head:         age  hours-per-week
# 0  2.048918        1.568702
# 1 -1.568306       -2.037764
# 2 -0.555483       -0.034172
# 3  1.397817       -0.034172
# 4 -0.989550       -0.034172
# Scaled train describe:                 age  hours-per-week
# count  3.942900e+04    3.942900e+04
# mean  -1.083051e-16   -3.243747e-17
# std    1.000013e+00    1.000013e+00
# min   -1.568306e+00   -3.159776e+00
# 25%   -7.725164e-01   -3.417220e-02
# 50%   -1.214163e-01   -3.417220e-02
# 75%    6.743728e-01    3.665463e-01
# max    3.712840e+00    4.694306e+00

# %%
# defining features and target for education
EDU_FEATURES = [col for col in train_df_encoding.columns
                if any(col.startswith(p) for p in
                      ['age', 'workclass', 'occupation', 'income',
                'marital', 'relationship', 'race', 'gender', 'hours'])]
EDU_TARGET = 'educational-num'

# splitting the data
X_edu = train_df_encoding[EDU_FEATURES]
y_edu = train_df_encoding[EDU_TARGET]

X_edu_train, X_edu_dev, y_edu_train, y_edu_dev = train_test_split(
    X_edu, y_edu, test_size=0.15, random_state=42)

print(X_edu_train.shape)
print(X_edu_dev.shape)
# Out:
# (33514, 47)
# (5915, 47)

# %%
bins = [0, 8, 12, 14, 17]
labels = [0, 1, 2, 3]  # 0=Low, 1=HS-level, 2=Some-college, 3=Advanced

y_edu_train_binned = pd.cut(y_edu_train, bins=bins, labels=labels).astype(int)
y_edu_dev_binned = pd.cut(y_edu_dev, bins=bins, labels=labels).astype(int)

# %%
# Model selection and prediction 

# Decision Tree
decision_tree= DecisionTreeClassifier(random_state=42, max_depth=10)

# fitting the classifier
decision_tree.fit(X_edu_train,y_edu_train_binned)

# making predictions
edu_y_prediction = decision_tree.predict(X_edu_dev)
edu_train_score = decision_tree.score(X_edu_train, y_edu_train_binned)
edu_dev_score = decision_tree.score(X_edu_dev, y_edu_dev_binned)
precision = precision_score(y_edu_dev_binned, edu_y_prediction,average='micro')
recall = recall_score(y_edu_dev_binned, edu_y_prediction, average='micro')

print(edu_y_prediction,edu_train_score,edu_dev_score, precision, recall)
print(classification_report(y_edu_dev_binned, edu_y_prediction, 
                            target_names = ['Low', 'HS-level', 'Some-college', 'Advanced']))
# Out:
# [1 2 1 ... 1 1 1] 0.7416900399832905 0.7144547759932375 0.7144547759932375 0.7144547759932375
#               precision    recall  f1-score   support
#
#          Low       0.74      0.19      0.30       705
#     HS-level       0.73      0.91      0.81      3702
# Some-college       0.65      0.49      0.56      1334
#     Advanced       0.63      0.33      0.43       174
#
#     accuracy                           0.71      5915
#    macro avg       0.69      0.48      0.52      5915
# weighted avg       0.71      0.71      0.68      5915

# %%
# Random Forest
rfedu = RandomForestClassifier(
    n_estimators=100,
    max_depth=10,
    random_state=42
)

# fitting the classifier
rfedu.fit(X_edu_train, y_edu_train_binned)

# making predictions
edu_y_prediction_rfedu = rfedu.predict(X_edu_dev)
edu_train_score_rfedu = rfedu.score(X_edu_train, y_edu_train_binned)
edu_dev_score_rfedu = rfedu.score(X_edu_dev, y_edu_dev_binned)
precision_rfedu = precision_score(y_edu_dev_binned, edu_y_prediction_rfedu, average='micro')
recall_rfedu = recall_score(y_edu_dev_binned, edu_y_prediction_rfedu, average='micro')

print(edu_y_prediction_rfedu, edu_train_score_rfedu, edu_dev_score_rfedu, precision_rfedu, recall_rfedu)
print(classification_report(
    y_edu_dev_binned,
    edu_y_prediction_rfedu,
    target_names=['Low', 'HS-level', 'Some-college', 'Advanced']
))
# Out:
# [1 2 1 ... 1 1 1] 0.7288297427940562 0.7120879120879121 0.7120879120879121 0.7120879120879121
#               precision    recall  f1-score   support
#
#          Low       0.92      0.15      0.26       705
#     HS-level       0.72      0.94      0.82      3702
# Some-college       0.65      0.44      0.52      1334
#     Advanced       0.75      0.16      0.26       174
#
#     accuracy                           0.71      5915
#    macro avg       0.76      0.42      0.47      5915
# weighted avg       0.73      0.71      0.67      5915

# %%
lr_edu = LinearRegression()
lr_edu.fit(X_edu_train, y_edu_train)

# predictions
y_edu_pred = lr_edu.predict(X_edu_dev)

y_edu_pred_binned = pd.cut(y_edu_pred, bins=bins, labels=labels).astype(int)

# scores
mse = mean_squared_error(y_edu_dev, y_edu_pred)
r2 = r2_score(y_edu_dev, y_edu_pred)
accuracy = accuracy_score(y_edu_dev_binned, y_edu_pred_binned)

print(f"MSE:      {mse:.4f}")
print(f"R2:       {r2:.4f}")
print(f"Accuracy: {accuracy:.4f}")

plt.figure(figsize=(6, 4))
plt.scatter(y_edu_dev, y_edu_pred, alpha=0.3, color='blue')
plt.plot([1, 16], [1, 16], color='red', linestyle='--', label='Perfect prediction')
plt.xlabel("Actual Education Level (1-16)")
plt.ylabel("Predicted Education Level")
plt.title("Linear Regression: Actual vs Predicted Education")
plt.legend()
plt.grid()
plt.show()
# Out:
# MSE:      3.7262
# R2:       0.3773
# Accuracy: 0.6803

# %%
# defining features and target for income 
INCOME_FEATURES = [col for col in train_df_encoding.columns
                if any(col.startswith(p) for p in
                      ['age', 'workclass', 'occupation', 'education',
                'marital', 'relationship', 'race', 'gender', 'hours', 'educational-num'])]
INCOME_TARGET = 'income_>50K'

# splitting the data
X_income = train_df_encoding[INCOME_FEATURES]
y_income = train_df_encoding[INCOME_TARGET]  # ← fixed from y_edu

X_inc_train, X_inc_dev, y_inc_train, y_inc_dev = train_test_split(
    X_income, y_income, test_size=0.15, random_state=42, stratify=y_income)  # ← fixed y_income

print(X_inc_train.shape)
print(X_inc_dev.shape)
# Out:
# (33514, 63)
# (5915, 63)

# %%
#linear regression 
lr= LogisticRegression(max_iter=1000)
lr.fit(X_inc_train, y_inc_train)

#predictions
y_inc_pred= lr.predict(X_inc_dev)

#scores
accuracy = accuracy_score(y_inc_dev, y_inc_pred)
y_inc_pred_prob = lr.predict_proba(X_inc_dev)[:, 1]

print(f"Accuracy: {accuracy:.4f}")

#plot
plt.figure(figsize=(6,4))
plt.scatter(y_inc_dev, y_inc_pred_prob, alpha=0.3, color='blue')
plt.axhline(0.5, color='red', linestyle='--', label='Decision threshold (0.5)')
plt.xlabel("Actual Income (0 or 1)")
plt.ylabel("Predicted Value")
plt.title("Logistic Regression: Actual vs Predicted Income")
plt.legend()
plt.grid()
plt.show()
# Out:
# Accuracy: 0.8309
